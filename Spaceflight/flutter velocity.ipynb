# %%
import math

Cr = 39.4 #root chord 
Ct = 19.7 #tip chord
b = 19.7 #sweep distance/semi-span
G = 3.5*10**6 #Shear Modulus
t = 0.5  #thickness
h = 3000 #height
T = 59-0.00356*h #temperature, room temp for now, change later

S = 1/2*(Cr+Ct)*b
AR = b*b/S
lam = Ct/Cr
a =  math.sqrt(1.4*1716.59*(T+459.7))
P = 2116*((T+459.7)/518.6)**5.256/144

Vf = a*math.sqrt(G/(1.337*AR**3*P*(lam+1))*2*(AR+2)*(t/Cr)**3)/1125
print(Vf)
